# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import confusion_matrix

# %%
# Turning csv's into DataFrames
chess_df = pd.read_csv(Path('games_edited.csv'))

# %%
chess_df.head()
# Out:
#          id  rated    created_at  last_move_at  turns victory_status winner  \
# 0  TZJHLljE  False  1.500000e+12  1.500000e+12     13      outoftime  white
# 1  l1NXvwaE   True  1.500000e+12  1.500000e+12     16         resign  black
# 2  mIICvQHh   True  1.500000e+12  1.500000e+12     61           mate  white
# 3  kWKvrqYL   True  1.500000e+12  1.500000e+12     61           mate  white
# 4  9tXo1AUZ   True  1.500000e+12  1.500000e+12     95           mate  white
#
#   increment_code       white_id  white_rating  ... black_rating  opening_eco  \
# 0           15+2       bourgris          1500  ...         1191          D10
# 1           5+10           a-00          1322  ...         1261          B00
# 2           5+10         ischia          1496  ...         1500          C20
# 3           20+0  daniamurashov          1439  ...         1454          D02
# 4           30+3      nik221107          1523  ...         1469          C41
#
#                              opening_name opening_ply  Move1A Move1B Move2A  \
# 0        Slav Defense: Exchange Variation           5      d4     d5     c4
# 1  Nimzowitsch Defense: Kennedy Variation           4      d4    Nc6     e4
# 2   King's Pawn Game: Leonardis Variation           3      e4     e5     d3
# 3  Queen's Pawn Game: Zukertort Variation           3      d4     d5    Nf3
# 4                        Philidor Defense           5      e4     e5    Nf3
#
#   Move2B Move3A Move3B
# 0     c6   cxd5     e6
# 1     e5     f4     f6
# 2     d6    Be3     c6
# 3    Bf5    Nc3    Nf6
# 4     d6     d4    Nc6
#
# [5 rows x 21 columns]

# %%
# Dropping the column that I want to predict on the training data
X_train = chess_df.drop('winner',axis = 1)

# %%
# Creating training data X and Y
X_dummies = pd.get_dummies(X_train)
y_train_label = LabelEncoder().fit_transform(chess_df['winner'])

# %%
# Creating testing data X and Y
X_test = chess_df.drop('winner',axis = 1)
X_dummies_test = pd.get_dummies(X_test).reindex(columns=X_dummies.columns,fill_value=0)
y_test_label = LabelEncoder().fit_transform(chess_df['winner'])
