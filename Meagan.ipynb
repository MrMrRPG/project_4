# %%
# Importing dependencies
import pandas as pd
import os
import csv
import requests
import json
from sqlalchemy import create_engine

# %%
# Find Chess.com usernames
url = "https://api.chess.com/pub/titled/GM"
response = requests.get(url).json()

# %%
# "Check" response... haha
print(response)
# Out:
# {'players': ['123lt', '124chess', '1977ivan', '1stsecond', '4thd-alpeacefulmoon', '64aramis64', '64arthos64', '64atilla64', '64dartagnan64', '64genghis64', '64leonidas64', '64porthos64', '64pyrrhus64', '731291', 'a-adly', 'a-fier', 'abasovn', 'abhidabhi', 'abhijeetgupta', 'abhijeetgupta1016', 'abhijeetonyoutube', 'abhyak', 'absentzest', 'abykhovsky', 'actorxu', 'adaro', 'adham_fawzy', 'adiosabu', 'afgano29', 'aggy67', 'agser', 'airgun1', 'aivanov-ne', 'akobian-sea', 'akobian-stl', 'akshatchandra', 'akshayraj_kore', 'alefedorov', 'aleksa74', 'aleksandrovaleksei', 'aleksey_sorokin', 'alexander-evdokimov', 'alexanderl', 'alexander_donchenko', 'alexander_moskalenko', 'alexander_zubov', 'alexandr_predke', 'alexchess1062', 'alexchess1984', 'alexcolovic', 'alexeishirov', 'alexhuzman', 'alexonischuk', 'alexrustemov', 'alexsur1981', 'alexvangog', 'alexyermo', 'alex_goloshchapov', 'alex_stripunsky', 'algeriano22', 'allanstig', 'almo64', 'alphaodin', 'amintabatabaei', 'amir-zaibi', 'amirbagheri78', 'amirreza_p', 'anaconda1983', 'anand', 'andabata', 'andrbaryshpolets', 'andreikka', 'andrei_belozerov', 'andrejs_sokolov', 'andreystukopin', 'andyrodri', 'angelogm', 'anishgiri', 'anishonyoutube', 'anka-sea', 'annawel', 'anna_muzychuk', 'anonymous1762', 'anthonywirig', 'antipov_mikhail_al', 'antonshomoev', 'antonsmirnov', 'anton_demchenko', 'anuar_is', 'anurag328', 'arabicfalcon', 'aradej', 'arambai', 'arcymisie', 'arencibia', 'argyllprince', 'ariancito1', 'arjunerigaisi2003', 'arkonada50', 'arm-akiba', 'armenianlion', 'arnaudovp', 'arseniy_nesterov', 'artem_ilyin', 'arthurkogan', 'art_vandelay1980', 'arvika', 'aryamabreu', 'aryangholami', 'aryantari', 'aryashitake', 'asadlivugar', 'aspired', 'assezde36', 'astralpulse', 'atalik', 'atomrod', 'attack2mateu', 'attackgm', 'attilaczebe', 'augustomatraga', 'avantage_ru', 'averagerecord', 'avetik_chessmood', 'avitalbor', 'avolodin', 'axves', 'aygehovit1992', 'azerichess', 'azerichessss', 'azeryahu', 'azgm', 'azikom', 'azzaro25', 'b-man', 'b-unit', 'babegroot', 'baby_legs', 'bacallao2019', 'bacyanide', 'baipi2010', 'baki83', 'bakki78', 'baku_boulevard', 'bancsoo', 'bankrotten', 'barcelona_guy', 'barcenilla-arz', 'bartoszsocko', 'barys1974', 'barzed', 'batica1984', 'batolovic', 'bazarov04', 'beca95', 'becerra-mia', 'beebucks', 'belabadea21', 'benjamin-nj', 'bentsfriend', 'berny643', 'besmall', 'bestcoacheverr', 'bfinegold-stl', 'bhat-sf', 'bigfish1995', 'bilelou', 'bilguunsu', 'billiekimbah', 'bilodeaua', 'blagid', 'blefer66', 'blindfoldkrikor', 'blindginger', 'blindlast7samurai', 'blindtakes', 'blueshark23', 'bluewizzard', 'bmw326', 'bobanbogosavljevic', 'bobbyhall222', 'bocah_sakit', 'bocharovd', 'bogdandeac', 'bonamente', 'bonca64', 'bonuspater18', 'boo786', 'boorrj', 'borisk62', 'bosiocic', 'brainwolf', 'brandonjacobson', 'brightthunder', 'brt6209', 'bryansmith', 'bubacik', 'bubi6', 'buffy7', 'bui2512', 'burbur555', 'bustedpack', 'bykhovsky-stl', 'byniolus', 'c-25', 'caefellion', 'caissa12', 'captainjames', 'carlosalbornoz', 'cassoulet', 'cayse', 'ccgrandmaster', 'cemilcan', 'ceraunophilmera', 'cerdasbrs', 'chabanon', 'chadaevnikolay', 'champ2005', 'charbonneau-ny', 'charlatante', 'checkmate_107', 'checky2015', 'checom', 'chefshouse', 'chepaschess', 'chernobay_artem', 'chessasuke', 'chessawp', 'chessbrah', 'chessdjw', 'chessdude', 'chesseducation4u', 'chessfatbear', 'chessfreak35', 'chessialist', 'chessking518', 'chessmastaflash88', 'chessmisic', 'chessmood', 'chessnerdstv', 'chessonado', 'chessonthemat007', 'chesspanda123', 'chessqueen', 'chessskool', 'chesstrainer2042', 'chesstraining77', 'chesswarrior7197', 'chessweebs', 'chesswolf1210', 'chesswy', 'chipsbeer', 'chirila-dal', 'chito89', 'chopper1905', 'chowman64', 'cipy77', 'classyel', 'clevercrab', 'coach_davido', 'cody1983', 'colchonero64', 'coldplace', 'colerranmorad', 'conquering', 'contora', 'copperbrain', 'courgete', 'crackcubano', 'crazyboy26', 'crescentmoon2411', 'cristhiancruzsanchez', 'cruel_yaro', 'cruise999', 'ctionescu', 'cubitas',  ...

# %%
# Small attempt for API Query
# Looping usernames to find number of followers
usernames = response["players"]
player_url = "https://api.chess.com/pub/player/"

responses = []
try:
    for username in usernames:
        chess_data = requests.get(player_url + username).json()
        responses.append(chess_data)
        print(f'Chess user {username} and has {chess_data["followers"]} followers')
except:
    print("next")
# Out:
# Chess user 123lt and has 72 followers
# Chess user 124chess and has 90 followers
# Chess user 1977ivan and has 130 followers
# Chess user 1stsecond and has 665 followers
# Chess user 4thd-alpeacefulmoon and has 3 followers
# Chess user 64aramis64 and has 12 followers
# Chess user 64arthos64 and has 4 followers
# Chess user 64atilla64 and has 7 followers
# Chess user 64dartagnan64 and has 19 followers
# Chess user 64genghis64 and has 3 followers
# Chess user 64leonidas64 and has 8 followers
# Chess user 64porthos64 and has 7 followers
# Chess user 64pyrrhus64 and has 1 followers
# Chess user 731291 and has 48 followers
# Chess user a-adly and has 409 followers
# Chess user a-fier and has 1190 followers
# Chess user abasovn and has 124 followers
# Chess user abhidabhi and has 539 followers
# Chess user abhijeetgupta and has 389 followers
# Chess user abhijeetgupta1016 and has 1186 followers
# Chess user abhijeetonyoutube and has 64 followers
# Chess user abhyak and has 22 followers
# Chess user absentzest and has 4 followers
# Chess user abykhovsky and has 153 followers
# Chess user actorxu and has 167 followers
# next

# %%
# More complicated, this time trying to get specific stat
# Example; Addind data to dataframe
usernames = response["players"]

# Create chess list
chess_data = []

responses = []
for username in usernames:
    player_stat_url = "https://api.chess.com/pub/player/" + username + "/stats"
    chess_json = requests.get(player_stat_url).json()
    player_info_url = "https://api.chess.com/pub/player/" + username
    player_json = requests.get(player_info_url).json()
    country_url = player_json["country"]
    country = requests.get(country_url).json()
    try:
        country_info = country["name"]
        blitz_win = chess_json["chess_blitz"]["record"]["win"]
        blitz_loss = chess_json["chess_blitz"]["record"]["loss"]
        blitz_draw = chess_json["chess_blitz"]["record"]["draw"]
        bullet_win = chess_json["chess_bullet"]["record"]["win"]
        bullet_loss = chess_json["chess_bullet"]["record"]["loss"]
        bullet_draw = chess_json["chess_bullet"]["record"]["draw"]
        rapid_win = chess_json["chess_rapid"]["record"]["win"]
        rapid_loss = chess_json["chess_rapid"]["record"]["loss"]
        rapid_draw = chess_json["chess_rapid"]["record"]["draw"]
        blitz_best_rating = chess_json["chess_blitz"]["best"]["rating"]
        bullet_best_rating = chess_json["chess_bullet"]["best"]["rating"]
        rapid_best_rating = chess_json["chess_rapid"]["best"]["rating"]
        chess_data.append({"Username": username,
                           "Country": country_info,
                          "Blitz Wins": blitz_win,
                            "Blitz Losses": blitz_loss,
                            "Blitz Draws": blitz_draw,
                            "Bullet Wins": bullet_win,
                            "Bullet Losses": bullet_loss,
                            "Bullet Draw": bullet_draw,
                            "Rapid Wins": rapid_win,
                            "Rapid Losses": rapid_loss,
                            "Rapid Draws": rapid_draw,
                            "Blitz Best Rating": blitz_best_rating,
                            "Bullet Best Rating": bullet_best_rating,
                           "Rapid Best Rating": rapid_best_rating,
                            })
        print("Data stored")
    except:
        print("next")
        pass
# Out:
# Data stored
# Data stored
# Data stored
# Data stored
# next
# next
# next
# next
# next
# next
# next
# next
# next
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# next
# Data stored
# next
# next
# Data stored
# next
# next
# Data stored
# next
# Data stored
# next
# next
# next
# next
# next
# next
# next
# Data stored
# next
# Data stored
# next
# Data stored
# next
# Data stored
# Data stored
# Data stored
# Data stored
# next
# next
# Data stored
# next
# Data stored
# next
# next
# Data stored
# next
# next
# Data stored
# next
# Data stored
# next
# Data stored
# next
# next
# Data stored
# Data stored
# Data stored
# Data stored
# next
# next
# next
# Data stored
# Data stored
# Data stored
# next
# Data stored
# next
# next
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# next
# next
# next
# next
# next
# Data stored
# next
# next
# next
# next
# Data stored
# next
# Data stored
# Data stored
# Data stored
# next
# next
# Data stored
# Data stored
# Data stored
# Data stored
# next
# Data stored
# Data stored
# next
# next
# Data stored
# next
# Data stored
# next
# Data stored
# next
# next
# next
# next
# Data stored
# next
# next
# Data stored
# Data stored
# next
# Data stored
# next
# Data stored
# next
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# next
# Data stored
# Data stored
# next
# Data stored
# next
# next
# next
# next
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# next
# next
# next
# next
# next
# Data stored
# Data stored
# next
# next
# next
# Data stored
# next
# Data stored
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# Data stored
# next
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# next
# Data stored
# next
# Data stored
# next
# next
# Data stored
# next
# next
# next
# next
# next
# Data stored
# next
# next
# next
# Data stored
# next
# next
# next
# Data stored
# Data stored
# Data stored
# next
# next
# next
# next
# next
# Data stored
# next
# Data stored
# next
# next
# Data stored
# next
# next
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# next
# next
# Data stored
# next
# next
# next
# next
# next
# next
# next
# Data stored
# Data stored
# Data stored
# Data stored
# next
# Data stored
# Data stored
# next
# next
# next
# next
# Data stored
# Data stored
# next
# next
# Data stored
# next
# next
# next
# next
# next
# next
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# next
# next
# Data stored
# next
# next
# Data stored
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# next
# Data stored
# next
# next
# next
# next
# Data stored
# next
# Data stored
# next
# Data stored
# Data stored
# next
# next
# next
# Data stored
# next
# Data stored
# next
# Data stored
# next
# Data stored
# next
# Data stored
# next
# next
# next
# Data stored
# next
# next
# Data stored
# next
# next
# Data stored
# next
# Data stored
# next
# next
# Data stored
# Data stored
# Data stored
# next
# next
# next
# next
# Data stored
# next
# Data stored
# Data stored
# Data stored
# next
# next
# next
# Data stored
# next
# next
# Data stored
# next
# Data stored
# next
# Data stored
# Data stored
# Data stored
# next
# next
# next
# Data stored
# Data stored
# Data stored
# Data stored
# next
# Data stored
# next
# Data stored
# next
# next
# next
# Data stored
# next
# Data stored
# Data stored
# Data stored
# next
# next
# next
# Data stored
# next
# Data stored
# next
# Data stored
# next
# Data stored
# Data stored
# next
# Data stored
# Data stored
# next
# next
# Data stored
# next
# next
# Data stored
# next
# next
# Data stored
# next
# next
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# next
# Data stored
# Data stored
# next
# Data stored
# next
# Data stored
# next
# Data stored
# next
# next
# next
# next
# next
# Data stored
# Data stored
# Data stored
# next
# Data stored
# Data stored
# next
# next
# next
# next
# next
# Data stored
# Data stored
# Data stored
# next
# next
# next
# next
# next
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# next
# next
# Data stored
# next
# next
# Data stored
# Data stored
# Data stored
# Data stored
# next
# next
# Data stored
# Data stored
# next
# next
# next
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# Data stored
# next
# next
# Data stored
# Data stored
# next
# next
# Data stored
# Data stored
# next
# next
# Data stored
# next
# next
# next
# next
# next
# next
# Data stored
# Data stored
# next
# next
# Data stored
# Data stored
# next
# Data stored
# next
# next
# Data stored
# next
# Data stored
# next
# Data stored
# next
# next
# next
# next
# next
# Data stored
# next
# Data stored
# next
# Data stored
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# next
# next
# next
# Data stored
# next
# next
# Data stored
# next
# Data stored
# Data stored
# next
# next
# Data stored
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# next
# Data stored
# next
# Data stored
# next
# next
# next
# Data stored
# next
# next
# next
# Data stored
# next
# next
# next
# next
# Data stored
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# next
# next
# next
# Data stored
# next
# Data stored
# Data stored
# Data stored
# Data stored
# next
# Data stored
# next
# next
# Data stored
# next
# next
# next
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# next
# Data stored
# Data stored
# next
# Data stored
# next
# next
# Data stored
# Data stored
# next
# next
# next
# next
# Data stored
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# Data stored
# next
# next
# Data stored
# next
# Data stored
# next
# next
# next
# next
# next
# Data stored
# next
# Data stored
# Data stored
# next
# next
# next
# Data stored
# next
# next
# Data stored
# next
# Data stored
# next
# next
# Data stored
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# next
# next
# Data stored
# Data stored
# next
# Data stored
# next
# next
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# next
# Data stored
# next
# Data stored
# Data stored
# next
# Data stored
# next
# Data stored
# next
# next
# Data stored
# Data stored
# next
# next
# Data stored
# next
# next
# next
# next
# Data stored
# next
# next
# next
# Data stored
# Data stored
# next
# next
# Data stored
# next
# next
# next
# next
# Data stored
# Data stored
# Data stored
# next
# Data stored
# next
# next
# Data stored
# next
# Data stored
# Data stored
# next
# next
# Data stored
# next
# Data stored
# Data stored
# Data stored
# Data stored
# next
# next
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# Data stored
# next
# next
# next
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# Data stored
# next
# next
# next
# Data stored
# Data stored
# next
# next
# Data stored
# next
# Data stored
# Data stored
# Data stored
# next
# next
# next
# Data stored
# Data stored
# Data stored
# next
# Data stored
# next
# Data stored
# next
# next
# next
# Data stored
# next
# Data stored
# Data stored
# next
# next
# next
# Data stored
# Data stored
# Data stored
# Data stored
# next
# Data stored
# Data stored
# next
# next
# next
# next
# Data stored
# Data stored
# next
# Data stored
# next
# next
# Data stored
# next
# next
# Data stored
# next
# next
# next
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# next
# Data stored
# next
# Data stored
# Data stored
# next
# next
# next
# Data stored
# Data stored
# next
# next
# next
# next
# next
# next
# Data stored
# Data stored
# Data stored
# next
# next
# next
# Data stored
# Data stored
# Data stored
# next
# Data stored
# next
# next
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# next
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# Data stored
# next
# Data stored
# next
# next
# Data stored
# next
# Data stored
# next
# Data stored
# next
# Data stored
# next
# next
# Data stored
# next
# next
# Data stored
# next
# next
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# next
# next
# Data stored
# Data stored
# next
# next
# next
# Data stored
# Data stored
# next
# next
# Data stored
# next
# Data stored
# Data stored
# Data stored
# Data stored
# next
# next
# Data stored
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# next
# Data stored
# next
# next
# Data stored
# Data stored
# next
# Data stored
# next
# next
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# Data stored
# next
# Data stored
# next
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# next
# Data stored
# Data stored
# next
# next
# next
# Data stored
# next
# Data stored
# next
# Data stored
# Data stored
# next
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# next
# next
# next
# Data stored
# next
# next
# next
# Data stored
# Data stored
# Data stored
# next
# next
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# next
# next
# Data stored
# next
# next
# Data stored
# next
# next
# Data stored
# next
# Data stored
# next
# next
# next
# next
# Data stored
# next
# next
# next
# Data stored
# next
# Data stored
# Data stored
# Data stored
# Data stored
# next
# Data stored
# next
# next
# next
# next
# Data stored
# next
# next
# Data stored
# Data stored
# next
# next
# next
# Data stored
# Data stored
# Data stored
# next
# Data stored
# next
# next
# Data stored
# next
# next
# next
# Data stored
# Data stored
# Data stored
# next
# next
# Data stored
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# Data stored
# next
# next
# Data stored
# next
# next
# next
# Data stored
# Data stored
# next
# next
# next
# next
# Data stored
# Data stored
# next
# Data stored
# next
# next
# next
# Data stored
# Data stored
# next
# next
# next
# next
# Data stored
# Data stored
# next
# next
# next
# Data stored
# next
# Data stored
# next
# Data stored
# next
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# next
# Data stored
# next
# next
# next
# next
# next
# next
# Data stored
# Data stored
# Data stored
# Data stored
# next
# next
# next
# next
# Data stored
# next
# next
# Data stored
# next
# next
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# next
# next
# next
# next
# Data stored
# next
# Data stored
# Data stored
# Data stored
# Data stored
# next
# Data stored
# next
# Data stored
# next
# next
# Data stored
# Data stored
# next
# Data stored
# next
# Data stored
# Data stored
# Data stored
# next
# next
# Data stored
# Data stored
# Data stored
# next
# next
# Data stored
# next
# next
# next
# Data stored
# Data stored
# next
# next
# next
# Data stored
# Data stored
# next
# Data stored
# next
# next
# next
# Data stored
# next
# next
# Data stored
# Data stored
# Data stored
# Data stored
# next
# Data stored
# next
# Data stored
# Data stored
# Data stored
# next
# next
# Data stored
# next
# next
# next
# next
# Data stored
# next
# Data stored
# next
# next
# next
# next
# Data stored
# next
# Data stored
# next
# Data stored
# Data stored
# next
# next
# next
# Data stored
# next
# Data stored
# Data stored
# next
# next
# next
# next
# next
# next
# Data stored
# next
# Data stored
# next
# next
# Data stored
# Data stored
# next
# Data stored
# next
# Data stored
# Data stored
# next
# Data stored
# Data stored
# next
# next
# next
# Data stored
# Data stored
# next
# next
# next
# Data stored
# Data stored
# next
# next
# next
# next
# Data stored
# Data stored
# next
# next
# next
# next
# Data stored
# next
# Data stored
# next
# Data stored
# next
# next
# Data stored
# next
# next
# Data stored
# next
# next
# next
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# next
# next
# Data stored
# next
# next
# Data stored
# next
# Data stored
# next
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# next
# next
# Data stored
# next
# next
# next
# next
# Data stored
# next
# Data stored
# next
# Data stored
# next
# next
# next
# next
# next
# Data stored
# next
# Data stored
# Data stored
# next
# next
# next
# next
# next
# next
# Data stored
# next
# next
# Data stored
# Data stored
# next
# next
# Data stored
# Data stored
# Data stored
# next
# Data stored
# Data stored
# Data stored
# Data stored
# next
# next
# Data stored
# next
# next
# next
# next
# Data stored
# next
# Data stored
# next
# Data stored
# next
# next
# Data stored
# next
# next
# next
# Data stored
# Data stored
# Data stored
# Data stored
# next
# next
# Data stored
# next
# Data stored
# Data stored
# Data stored
# next
# Data stored
# next
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# Data stored
# next
# next
# Data stored
# Data stored
# Data stored
# next
# next
# next
# Data stored
# Data stored
# next
# next
# next
# Data stored
# next
# next
# next
# Data stored
# Data stored
# Data stored
# Data stored
# next
# next
# Data stored
# next
# next
# next
# Data stored
# Data stored
# Data stored
# Data stored

# %%
# Create Dataframe
chess_df = pd.DataFrame(chess_data)

# Display head of dataframe
chess_df.head()
# Out:
#     Username Country  Blitz Wins  Blitz Losses  Blitz Draws  Bullet Wins  \
# 0      123lt   China         751           688          138          255
# 1   124chess  Russia        1230          1029          238           70
# 2   1977ivan  Serbia         734           402           85            2
# 3  1stsecond  Latvia        5342          4155          774         1007
# 4     731291   Spain        2732          2143          525          327
#
#    Bullet Losses  Bullet Draw  Rapid Wins  Rapid Losses  Rapid Draws  \
# 0            197           23          13             4            7
# 1             74            7           6             1            2
# 2              0            0           8             9            3
# 3            834          147          15             9            3
# 4            184           25          17            10            6
#
#    Blitz Best Rating  Bullet Best Rating  Rapid Best Rating
# 0               2707                2824               2509
# 1               2830                2605               2350
# 2               2824                2075               2556
# 3               2932                2872               2608
# 4               2770                2643               2470

# %%
# Export city data to csv
# Output File (CSV)
Data_CSV_file = "Data_CSV/chess.csv"
chess_df.to_csv(Data_CSV_file, index = False)

# %% [markdown]
# ------------------------------
# Creating Women Grand Master CSV

# %%
# Find Women Chess Masterusernames
wgm_url = "https://api.chess.com/pub/titled/WGM"
wgm_response = requests.get(wgm_url).json()
wgm_usernames = wgm_response["players"]
wgm_usernames
# Out:
# ['abrahamyan-la',
#  'adriananikolova',
#  'advantagelucy',
#  'ahachess',
#  'alexa797',
#  'ambotsari',
#  'anastasiyakarlovych',
#  'anjelina',
#  'anjood',
#  'ankudinova_yelena',
#  'anne93',
#  'anothergrumpy',
#  'armqueen',
#  'artemidaa',
#  'ati1517',
#  'atousa1',
#  'aurachess10',
#  'awarak',
#  'axvesik',
#  'backlight26',
#  'bairakovanova',
#  'belakovskaia-arz',
#  'betulcemreyildiz',
#  'bgrabarska',
#  'budu44',
#  'cam2015',
#  'camillab',
#  'carolinalujan',
#  'checkitas',
#  'chess9406',
#  'chesshh11',
#  'chesshippopotamchik',
#  'chessterra87',
#  'clauamura',
#  'clausanluis',
#  'clg_nemsko',
#  'coachirina',
#  'crazy_girl99',
#  'crisfoisor',
#  'cruziana',
#  'cukus',
#  'dariavoit',
#  'dauletova',
#  'demeter39',
#  'dey2580',
#  'dianadarchia',
#  'dinabelenkaya',
#  'earthen_deer',
#  'elena1668',
#  'elviraberend',
#  'enkhtuul',
#  'evgeniamescheriakova',
#  'fatianova_t',
#  'flawless_fighter',
#  'fleur_syigestie',
#  'flexova',
#  'govalya',
#  'gvetadze',
#  'heredia-stl',
#  'hotella',
#  'iljushina_olga',
#  'ilzeberzina',
#  'inga83',
#  'iozefinaw',
#  'iribu',
#  'irina_s18',
#  'irina_sudakova',
#  'irina_turova',
#  'ivavidenova',
#  'jabberwockiez',
#  'janakrivec',
#  'jauburn',
#  'jenia84',
#  'jenshahade',
#  'jilinzhang',
#  'jinbojinbo',
#  'jmf24',
#  'joannadworakowska',
#  'jolie92',
#  'jordanasoul',
#  'josefineheinemann',
#  'kajaol',
#  'katoma',
#  'ketitsatsalashvili',
#  'kettichess',
#  'khayala13',
#  'kiranmanisha',
#  'klavdia_nik',
#  'koenigin94',
#  'kopeisk81',
#  'krapinek9',
#  'kungmongmanh',
#  'lanita_1408',
#  'lenkaptacnikova',
#  'lexiel',
#  'lisychess',
#  'liverpoolborn',
#  'lizasolovyova',
#  'lumi22',
#  'lynette2015',
#  'mahri73',
#  'maili15',
#  'majoa88',
#  'mammadyarova',
#  'mariafominykh',
#  'marinamakro',
#  'martabartel',
#  'martinique24',
#  'maryann19',
#  'medalja',
#  'meenakshiwgm',
#  'melanielubbe',
#  'meoluoi91',
#  'meri-arabidze',
#  'mezioudamina88',
#  'mihaela_sandu',
#  'millenium19',
#  'mirandamikadze',
#  'mirochka',
#  'miupiu',
#  'mona_khaled',
#  'monicalzetta',
#  'monikaseps',
#  'morshynska',
#  'nara_kh',
#  'narmin_26',
#  'nastaj',
#  'nataliaedzgveradze',
#  'natalia_pogonina',
#  'nemsko',
#  'ninjaturtle04',
#  'ninomaisuradze',
#  'ninullia',
#  'novareina',
#  'ntmh281',
#  'ole83',
#  'olga_girya',
#  'olghita64',
#  'olifantcz',
#  'onlytime4',
#  'pandazero',
#  'parcerita1',
#  'pavalamalli',
#  'penguiinqueen',
#  'phoenix_sjh',
#  'pomoc',
#  'praguequeen',
#  'pratyusha18',
#  'rainbow2014',
#  'roosters19',
#  'sahara88',
#  'sakkcapak',
#  'samantha_ross',
#  'sanda81',
#  'sanyura',
#  'saraisitave',
#  'scarifplayer',
#  'sharevich-stl',
#  'shata1974',
#  'shrookwafa',
#  'slowdumbb',
#  'smilingice',
#  'solozhenkina_e',
#  'stacey2020',
#  'svetlanagm',
#  'swati4chess',
#  'sylvanaswindrunner',
#  'tanzja',
#  'tenamu',
#  'terezarodshtein',
#  'thehappyfarmer',
#  'tianachess',
#  'ticobello',
#  'tinatim12',
#  'tomilen',
#  'totoro9',
#  'ulkaf961',
#  'vaishali2001',
#  'varshi_chess',
#  'veranebolsina',
#  'vesnamisanovic',
#  'vitachulivska',
#  'vwnv7',
#  'wgmanna',
#  'wgmcarlaheredia',
#  'wgm_irina_mikhaylova',
#  'whitefalcon_2',
#  'winnie1989',
#  'winw1n',
#  'xanim01',
#  'xiaopang123',
#  'xuyuanyuan',
#  'yaris9',
#  'yennefer1',
#  'yileai',
#  'zefirka',
#  'zombik1']

# %%
eg_wgm_url = "https://api.chess.com/pub/player/jenshahade/stats"
without_stat = "https://api.chess.com/pub/player/jenshahade"
wgm_example = requests.get(eg_wgm_url).json()
print(json.dumps(wgm_example, indent=4, sort_keys=True))
# Out:
# {
#     "chess960_daily": {
#         "best": {
#             "date": 1571106563,
#             "game": "https://www.chess.com/game/daily/83901196",
#             "rating": 1440
#         },
#         "last": {
#             "date": 1571106563,
#             "rating": 1440,
#             "rd": 265
#         },
#         "record": {
#             "draw": 1,
#             "loss": 0,
#             "time_per_move": 208951,
#             "timeout_percent": 0,
#             "win": 5
#         }
#     },
#     "chess_blitz": {
#         "best": {
#             "date": 1582575634,
#             "game": "https://www.chess.com/game/live/4437411468",
#             "rating": 2252
#         },
#         "last": {
#             "date": 1632763238,
#             "rating": 2088,
#             "rd": 45
#         },
#         "record": {
#             "draw": 80,
#             "loss": 470,
#             "win": 572
#         }
#     },
#     "chess_bullet": {
#         "best": {
#             "date": 1484844780,
#             "game": "https://www.chess.com/game/live/1501020079",
#             "rating": 2202
#         },
#         "last": {
#             "date": 1602985946,
#             "rating": 2038,
#             "rd": 75
#         },
#         "record": {
#             "draw": 80,
#             "loss": 1087,
#             "win": 1276
#         }
#     },
#     "chess_daily": {
#         "best": {
#             "date": 1471128273,
#             "game": "https://www.chess.com/game/daily/136441686",
#             "rating": 2111
#         },
#         "last": {
#             "date": 1628020190,
#             "rating": 1561,
#             "rd": 148
#         },
#         "record": {
#             "draw": 0,
#             "loss": 4,
#             "time_per_move": 208951,
#             "timeout_percent": 0,
#             "win": 17
#         }
#     },
#     "chess_rapid": {
#         "last": {
#             "date": 1592898344,
#             "rating": 1296,
#             "rd": 100
#         },
#         "record": {
#             "draw": 0,
#             "loss": 1,
#             "win": 0
#         }
#     },
#     "fide": 2322,
#     "lessons": {
#         "highest": {
#             "date": 1385163971,
#             "rating": 2375
#         },
#         "lowest": {
#             "date": 1385163932,
#             "rating": 2278
#         }
#     },
#     "puzzle_rush": {
#         "best": {
#             "score": 39,
#             "total_attempts": 42
#         },
#         "daily": {
#             "score": 35,
#             "total_attempts": 38
#         }
#     },
#     "tactics": {
#         "highest": {
#             "date": 1569871848,
#             "rating": 2430
#         },
#         "lowest": {
#             "date": 1286921846,
#             "rating": 1347
#         }
#     }
# }

# %%
# More complicated, this time trying to get specific stat
# Example; Addind data to dataframe
wgm_usernames = wgm_response["players"]

# Create chess list
wgm_chess_data = []

responses = []
for username in usernames:
    player_stat_url = "https://api.chess.com/pub/player/" + username + "/stats"
    chess_json = requests.get(player_stat_url).json()
    player_info_url = "https://api.chess.com/pub/player/" + username
    player_json = requests.get(player_info_url).json()
    country_url = player_json["country"]
    country = requests.get(country_url).json()
    try:
        country_info = country["name"]
        blitz_win = chess_json["chess_blitz"]["record"]["win"]
        blitz_loss = chess_json["chess_blitz"]["record"]["loss"]
        blitz_draw = chess_json["chess_blitz"]["record"]["draw"]
        bullet_win = chess_json["chess_bullet"]["record"]["win"]
        bullet_loss = chess_json["chess_bullet"]["record"]["loss"]
        bullet_draw = chess_json["chess_bullet"]["record"]["draw"]
        rapid_win = chess_json["chess_rapid"]["record"]["win"]
        rapid_loss = chess_json["chess_rapid"]["record"]["loss"]
        rapid_draw = chess_json["chess_rapid"]["record"]["draw"]
        blitz_best_rating = chess_json["chess_blitz"]["best"]["rating"]
        bullet_best_rating = chess_json["chess_bullet"]["best"]["rating"]
        rapid_best_rating = chess_json["chess_rapid"]["best"]["rating"]
        wgm_chess_data.append({"Username": username,
                           "Country": country_info,
                          "Blitz Wins": blitz_win,
                            "Blitz Losses": blitz_loss,
                            "Blitz Draws": blitz_draw,
                            "Bullet Wins": bullet_win,
                            "Bullet Losses": bullet_loss,
                            "Bullet Draw": bullet_draw,
                            "Rapid Wins": rapid_win,
                            "Rapid Losses": rapid_loss,
                            "Rapid Draws": rapid_draw,
                            "Blitz Best Rating": blitz_best_rating,
                            "Bullet Best Rating": bullet_best_rating,
                           "Rapid Best Rating": rapid_best_rating,
                            })
        print("Data stored")
    except:
        print("next")
        pass

# %% [markdown]
# -------------------
# Creating JSON File

# %%
def csv_to_json(csvFilePath, jsonFilePath):
    jsonArray = []
      
    #read csv file
    with open(csvFilePath, encoding='utf-8') as csvf: 
        #load csv file data using csv library's dictionary reader
        csvReader = csv.DictReader(csvf) 

        #convert each csv row into python dict
        for row in csvReader: 
            #add this python dict to json array
            jsonArray.append(row)
  
    #convert python jsonArray to JSON String and write to file
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf: 
        jsonString = json.dumps(jsonArray, indent=4)
        jsonf.write(jsonString)
          
csvFilePath = "Data_CSV/chess.csv"
jsonFilePath = "static/chess.json"
csv_to_json(csvFilePath, jsonFilePath)
